# %% [markdown]
# ### Github link: https://github.com/Asimsayam/student-data-set/upload/main

# %% [markdown]
# Data cleaning

# %%
import pandas as pd

# %%
df= pd.read_csv("student.csv")

# %%
df.isnull().sum()
# Out:
# school          0
# sex             0
# age             0
# address         0
# famsize         0
# Pstatus         0
# Medu            0
# Fedu            0
# Mjob            2
# Fjob            0
# guardian        0
# traveltime      0
# studytime       0
# failures        0
# Ssupport        0
# Gsupport        0
# feespaid        0
# ecactivities    0
# internet        0
# freetime        0
# goout           0
# health          0
# absences        0
# G1              0
# G2              0
# G3              0
# dtype: int64

# %%
df.dropna()
# remove empty cells
# give new
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.dropna(inplace=True)

# change the original

# %%
df.fillna(9)
#replace empty cells with new value
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   feespaid  ecactivities  internet  freetime goout health absences  G1  G2  G3
# 0       no            no        no         3     4      3        6   5   6   6
# 1       no            no       yes         3     3      3        4   5   5   6
# 2      yes            no       yes         3     2      3       10   7   8  10
# 3      yes           yes       yes         2     2      5        2  15  14  15
# 4      yes            no        no         3     2      5        4   6  10  10
#
# [5 rows x 26 columns]

# %%
df["age"].fillna(879)
# specific columns
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
# 5      16
# 6      16
# 8      15
# 9      15
# 10     15
# 11     15
# 13     15
# 14     15
# 15     16
# 16     16
# 17     16
# 18     17
# 19     16
# 20     15
# 21     15
# 22     16
# 23     16
# 24     15
# 25     16
# 26     15
# 27     15
# 28     16
# 29     16
# 30     15
# 31     15
# 32     15
# 33     15
# 34     16
# 35     15
# 36     15
# 37     16
# 38     15
# 39     15
# 40     16
# 41     15
# 42     15
# 43     15
# 44     16
# 45     15
# 46     16
# 47     16
# 48     15
# 49     15
# 50     16
# 51     15
# 52     15
# 53     15
# 54     15
# 55     16
# 56     15
# 57     15
# 58     15
# 59     16
# 60     16
# 61     16
# 62     16
# 63     16
# 64     15
# 65     16
# 66     15
# 67     16
# 68     15
# 69     15
# 70     16
# 71     15
# 72     15
# 73     16
# 74     16
# 75     15
# 76     15
# 77     16
# 78     17
# 79     16
# 80     15
# 81     15
# 82     15
# 83     15
# 84     15
# ...

# %%
x=df["age"].mean()
df["age"].fillna(x)
#fill mean at age
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
# 5      16
# 6      16
# 8      15
# 9      15
# 10     15
# 11     15
# 13     15
# 14     15
# 15     16
# 16     16
# 17     16
# 18     17
# 19     16
# 20     15
# 21     15
# 22     16
# 23     16
# 24     15
# 25     16
# 26     15
# 27     15
# 28     16
# 29     16
# 30     15
# 31     15
# 32     15
# 33     15
# 34     16
# 35     15
# 36     15
# 37     16
# 38     15
# 39     15
# 40     16
# 41     15
# 42     15
# 43     15
# 44     16
# 45     15
# 46     16
# 47     16
# 48     15
# 49     15
# 50     16
# 51     15
# 52     15
# 53     15
# 54     15
# 55     16
# 56     15
# 57     15
# 58     15
# 59     16
# 60     16
# 61     16
# 62     16
# 63     16
# 64     15
# 65     16
# 66     15
# 67     16
# 68     15
# 69     15
# 70     16
# 71     15
# 72     15
# 73     16
# 74     16
# 75     15
# 76     15
# 77     16
# 78     17
# 79     16
# 80     15
# 81     15
# 82     15
# 83     15
# 84     15
# ...

# %%
x=df["age"].median()
df["age"].fillna(x)
#fill median at age
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
# 5      16
# 6      16
# 8      15
# 9      15
# 10     15
# 11     15
# 13     15
# 14     15
# 15     16
# 16     16
# 17     16
# 18     17
# 19     16
# 20     15
# 21     15
# 22     16
# 23     16
# 24     15
# 25     16
# 26     15
# 27     15
# 28     16
# 29     16
# 30     15
# 31     15
# 32     15
# 33     15
# 34     16
# 35     15
# 36     15
# 37     16
# 38     15
# 39     15
# 40     16
# 41     15
# 42     15
# 43     15
# 44     16
# 45     15
# 46     16
# 47     16
# 48     15
# 49     15
# 50     16
# 51     15
# 52     15
# 53     15
# 54     15
# 55     16
# 56     15
# 57     15
# 58     15
# 59     16
# 60     16
# 61     16
# 62     16
# 63     16
# 64     15
# 65     16
# 66     15
# 67     16
# 68     15
# 69     15
# 70     16
# 71     15
# 72     15
# 73     16
# 74     16
# 75     15
# 76     15
# 77     16
# 78     17
# 79     16
# 80     15
# 81     15
# 82     15
# 83     15
# 84     15
# ...

# %%
x=df["age"].mode()[0]
df["age"].fillna(x)
#fill mode at age
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
# 5      16
# 6      16
# 8      15
# 9      15
# 10     15
# 11     15
# 13     15
# 14     15
# 15     16
# 16     16
# 17     16
# 18     17
# 19     16
# 20     15
# 21     15
# 22     16
# 23     16
# 24     15
# 25     16
# 26     15
# 27     15
# 28     16
# 29     16
# 30     15
# 31     15
# 32     15
# 33     15
# 34     16
# 35     15
# 36     15
# 37     16
# 38     15
# 39     15
# 40     16
# 41     15
# 42     15
# 43     15
# 44     16
# 45     15
# 46     16
# 47     16
# 48     15
# 49     15
# 50     16
# 51     15
# 52     15
# 53     15
# 54     15
# 55     16
# 56     15
# 57     15
# 58     15
# 59     16
# 60     16
# 61     16
# 62     16
# 63     16
# 64     15
# 65     16
# 66     15
# 67     16
# 68     15
# 69     15
# 70     16
# 71     15
# 72     15
# 73     16
# 74     16
# 75     15
# 76     15
# 77     16
# 78     17
# 79     16
# 80     15
# 81     15
# 82     15
# 83     15
# 84     15
# ...

# %%
df["age"]
#age column
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
# 5      16
# 6      16
# 8      15
# 9      15
# 10     15
# 11     15
# 13     15
# 14     15
# 15     16
# 16     16
# 17     16
# 18     17
# 19     16
# 20     15
# 21     15
# 22     16
# 23     16
# 24     15
# 25     16
# 26     15
# 27     15
# 28     16
# 29     16
# 30     15
# 31     15
# 32     15
# 33     15
# 34     16
# 35     15
# 36     15
# 37     16
# 38     15
# 39     15
# 40     16
# 41     15
# 42     15
# 43     15
# 44     16
# 45     15
# 46     16
# 47     16
# 48     15
# 49     15
# 50     16
# 51     15
# 52     15
# 53     15
# 54     15
# 55     16
# 56     15
# 57     15
# 58     15
# 59     16
# 60     16
# 61     16
# 62     16
# 63     16
# 64     15
# 65     16
# 66     15
# 67     16
# 68     15
# 69     15
# 70     16
# 71     15
# 72     15
# 73     16
# 74     16
# 75     15
# 76     15
# 77     16
# 78     17
# 79     16
# 80     15
# 81     15
# 82     15
# 83     15
# 84     15
# ...

# %%
df.loc[1,'age']=69
# replace specific value

# %%
df['age']
# Out:
# 0      18
# 1      69
# 2      15
# 3      15
# 4      16
# 5      16
# 6      16
# 8      15
# 9      15
# 10     15
# 11     15
# 13     15
# 14     15
# 15     16
# 16     16
# 17     16
# 18     17
# 19     16
# 20     15
# 21     15
# 22     16
# 23     16
# 24     15
# 25     16
# 26     15
# 27     15
# 28     16
# 29     16
# 30     15
# 31     15
# 32     15
# 33     15
# 34     16
# 35     15
# 36     15
# 37     16
# 38     15
# 39     15
# 40     16
# 41     15
# 42     15
# 43     15
# 44     16
# 45     15
# 46     16
# 47     16
# 48     15
# 49     15
# 50     16
# 51     15
# 52     15
# 53     15
# 54     15
# 55     16
# 56     15
# 57     15
# 58     15
# 59     16
# 60     16
# 61     16
# 62     16
# 63     16
# 64     15
# 65     16
# 66     15
# 67     16
# 68     15
# 69     15
# 70     16
# 71     15
# 72     15
# 73     16
# 74     16
# 75     15
# 76     15
# 77     16
# 78     17
# 79     16
# 80     15
# 81     15
# 82     15
# 83     15
# 84     15
# ...

# %%
print(df.duplicated())
# to find duplicate row
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Length: 393, dtype: bool

# %%
df.drop_duplicates()
# remove duplicated value
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  393.000000  393.000000  393.000000  393.000000  393.000000  393.000000
# mean    17.508906    2.743003    2.513995    1.447837    2.038168    0.335878
# std      2.695527    1.093864    1.085824    0.698359    0.839745    0.745161
# min     17.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     17.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     69.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#          freetime       goout      health    absences          G1          G2  \
# count  393.000000  393.000000  393.000000  393.000000  393.000000  393.000000
# mean     3.241730    3.106870    3.557252    5.717557   10.913486   10.720102
# ...

# %%
df['col']=6
#add new column
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.head()
# Out:
#    age  addres sex school address famsize Pstatus  Medu  Fedu      Mjob  ...  \
# 1   17     NaN   F     GP       U     GT3       T   1.0   1.0   at_home  ...
# 2   15     NaN   F     GP       U     LE3       T   1.0   1.0   at_home  ...
# 3   15     NaN   F     GP       U     GT3       T   4.0   2.0    health  ...
# 4   16     NaN   F     GP       U     GT3       T   3.0   3.0     other  ...
# 5   16     NaN   M     GP       U     LE3       T   4.0   3.0  services  ...
#
#   feespaid ecactivities  internet  freetime  goout health absences    G1  \
# 1       no           no       yes       3.0    3.0    3.0      4.0   5.0
# 2      yes           no       yes       3.0    2.0    3.0     10.0   7.0
# 3      yes          yes       yes       2.0    2.0    5.0      2.0  15.0
# 4      yes           no        no       3.0    2.0    5.0      4.0   6.0
# 5      yes          yes       yes       4.0    2.0    5.0     10.0  15.0
#
#      G2    G3
# 1   5.0   6.0
# 2   8.0  10.0
# 3  14.0  15.0
# ...

# %%
df.drop(0,inplace=True)
df
#index 0 deleted
# Out:
#      age  addres sex school address famsize Pstatus  Medu  Fedu      Mjob  \
# 1     17     NaN   F     GP       U     GT3       T   1.0   1.0   at_home
# 2     15     NaN   F     GP       U     LE3       T   1.0   1.0   at_home
# 3     15     NaN   F     GP       U     GT3       T   4.0   2.0    health
# 4     16     NaN   F     GP       U     GT3       T   3.0   3.0     other
# 5     16     NaN   M     GP       U     LE3       T   4.0   3.0  services
# ..   ...     ...  ..    ...     ...     ...     ...   ...   ...       ...
# 390   20     NaN   M     MS       U     LE3       A   2.0   2.0  services
# 391   17     NaN   M     MS       U     LE3       T   3.0   1.0  services
# 392   21     NaN   M     MS       R     GT3       T   1.0   1.0     other
# 393   18     NaN   M     MS       R     LE3       T   3.0   2.0  services
# 394   19     NaN   M     MS       U     LE3       T   1.0   1.0     other
#
#      ... feespaid ecactivities  internet  freetime  goout health absences  \
# ...

# %%
df[2:5]
# slicing
# Out:
#    age  addres sex school address famsize Pstatus  Medu  Fedu      Mjob  ...  \
# 3   15     NaN   F     GP       U     GT3       T   4.0   2.0    health  ...
# 4   16     NaN   F     GP       U     GT3       T   3.0   3.0     other  ...
# 5   16     NaN   M     GP       U     LE3       T   4.0   3.0  services  ...
#
#   feespaid ecactivities  internet  freetime  goout health absences    G1  \
# 3      yes          yes       yes       2.0    2.0    5.0      2.0  15.0
# 4      yes           no        no       3.0    2.0    5.0      4.0   6.0
# 5      yes          yes       yes       4.0    2.0    5.0     10.0  15.0
#
#      G2    G3
# 3  14.0  15.0
# 4  10.0  10.0
# 5  15.0  15.0
#
# [3 rows x 27 columns]

# %%
df[1:7:2]
# start,stop,step
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 5     GP   M   16       U     LE3       T     4     3  services     other
#
#    ... ecactivities  internet  freetime  goout health absences  G1  G2  G3  \
# 1  ...           no       yes         3      3      3        4   5   5   6
# 3  ...          yes       yes         2      2      5        2  15  14  15
# 5  ...          yes       yes         4      2      5       10  15  15  15
#
#    col
# 1    6
# 3    6
# 5    6
#
# [3 rows x 27 columns]

# %% [markdown]
# Data processing

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'guardian', 'traveltime', 'studytime', 'failures',
#        'Ssupport', 'Gsupport', 'feespaid', 'ecactivities', 'internet',
#        'freetime', 'goout', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.rename(columns={'sex':'gender'})
# Out:
#     school gender  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0       GP      F   18       U     GT3       A     4     4   at_home
# 1       GP      F   17       U     GT3       T     1     1   at_home
# 2       GP      F   15       U     LE3       T     1     1   at_home
# 3       GP      F   15       U     GT3       T     4     2    health
# 4       GP      F   16       U     GT3       T     3     3     other
# ..     ...    ...  ...     ...     ...     ...   ...   ...       ...
# 390     MS      M   20       U     LE3       A     2     2  services
# 391     MS      M   17       U     LE3       T     3     1  services
# 392     MS      M   21       R     GT3       T     1     1     other
# 393     MS      M   18       R     LE3       T     3     2  services
# 394     MS      M   19       U     LE3       T     1     1     other
#
#          Fjob  ... feespaid  ecactivities  internet  freetime goout health  \
# ...

# %%
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   feespaid  ecactivities  internet  freetime goout health absences  G1  G2  G3
# 0       no            no        no         3     4      3        6   5   6   6
# 1       no            no       yes         3     3      3        4   5   5   6
# 2      yes            no       yes         3     2      3       10   7   8  10
# 3      yes           yes       yes         2     2      5        2  15  14  15
# 4      yes            no        no         3     2      5        4   6  10  10
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (393, 27)

# %%
df.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... feespaid  ecactivities  internet  freetime goout health absences  G1  \
# 390  ...      yes            no        no         5     4      4       11   9
# 391  ...       no            no       yes         4     5      2        3  14
# 392  ...       no            no        no         5     3      3        3  10
# 393  ...       no            no       yes         4     1      5        0  11
# 394  ...       no            no       yes         2     3      5        5   8
#
#      G2  G3
# 390   9   9
# 391  16  16
# ...

# %%
df.sample(2)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu    Mjob   Fjob  ...  \
# 376     MS   F   20       U     GT3       T     4     2  health  other  ...
# 226     GP   F   17       U     GT3       T     3     2   other  other  ...
#
#     feespaid  ecactivities  internet  freetime goout health absences  G1  G2  \
# 376      yes            no       yes         4     3      3        4  15  14
# 226       no           yes       yes         3     4      3       10  16  15
#
#      G3
# 376  15
# 226  15
#
# [2 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   school        395 non-null    object
#  1   sex           395 non-null    object
#  2   age           395 non-null    int64
#  3   address       395 non-null    object
#  4   famsize       395 non-null    object
#  5   Pstatus       395 non-null    object
#  6   Medu          395 non-null    int64
#  7   Fedu          395 non-null    int64
#  8   Mjob          393 non-null    object
#  9   Fjob          395 non-null    object
#  10  guardian      395 non-null    object
#  11  traveltime    395 non-null    int64
#  12  studytime     395 non-null    int64
#  13  failures      395 non-null    int64
#  14  Ssupport      395 non-null    object
#  15  Gsupport      395 non-null    object
#  16  feespaid      395 non-null    object
#  17  ecactivities  395 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#          freetime       goout      health    absences          G1          G2  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.235443    3.108861    3.554430    5.708861   10.908861   10.713924
# ...

# %%
a =df.describe(include="all")
a.loc[["top","mean"]]
# loc use name
# Out:
#      school  sex        age address famsize Pstatus      Medu      Fedu  \
# top      GP    F        NaN       U     GT3       T       NaN       NaN
# mean    NaN  NaN  16.699746     NaN     NaN     NaN  2.743003  2.513995
#
#        Mjob   Fjob  ... feespaid  ecactivities  internet  freetime    goout  \
# top   other  other  ...       no           yes       yes       NaN      NaN
# mean    NaN    NaN  ...      NaN           NaN       NaN   3.24173  3.10687
#
#         health  absences         G1         G2         G3
# top        NaN       NaN        NaN        NaN        NaN
# mean  3.557252  5.717557  10.913486  10.720102  10.417303
#
# [2 rows x 26 columns]

# %%
df.loc[2:10,['school','internet']]
# Out:
#    school internet
# 2      GP      yes
# 3      GP      yes
# 4      GP       no
# 5      GP      yes
# 6      GP      yes
# 7      GP       no
# 8      GP      yes
# 9      GP      yes
# 10     GP      yes

# %%
df.iloc[2:10,3:12]
# use index
# Out:
#   address famsize Pstatus  Medu  Fedu      Mjob      Fjob guardian  traveltime
# 2       U     LE3       T     1     1   at_home     other   mother           1
# 3       U     GT3       T     4     2    health  services   mother           1
# 4       U     GT3       T     3     3     other     other   father           1
# 5       U     LE3       T     4     3  services     other   mother           1
# 6       U     LE3       T     2     2     other     other   mother           1
# 7       U     GT3       A     4     4       NaN   teacher   mother           2
# 8       U     LE3       A     3     2  services     other   mother           1
# 9       U     GT3       T     3     4     other     other   mother           1

# %%
a.iloc[[0,1,3]]
# Out:
#        school  sex    age address famsize Pstatus   Medu   Fedu Mjob Fjob  \
# count     395  395  395.0     395     395     395  395.0  395.0  393  395
# unique      2    2    NaN       2       2       2    NaN    NaN    5    5
# freq      349  208    NaN     307     281     354    NaN    NaN  140  217
#
#         ... feespaid  ecactivities  internet  freetime  goout health absences  \
# count   ...      395           395       395     395.0  395.0  395.0    395.0
# unique  ...        2             2         2       NaN    NaN    NaN      NaN
# freq    ...      214           201       329       NaN    NaN    NaN      NaN
#
#            G1     G2     G3
# count   395.0  395.0  395.0
# unique    NaN    NaN    NaN
# freq      NaN    NaN    NaN
#
# [3 rows x 26 columns]

# %%
pd.set_option('display.max_row',None)
pd.set_option('display.max_columns',None)
df[["address","age"]]
# Out:
#     address  age
# 0         U   18
# 1         U   17
# 2         U   15
# 3         U   15
# 4         U   16
# 5         U   16
# 6         U   16
# 8         U   15
# 9         U   15
# 10        U   15
# 11        U   15
# 13        U   15
# 14        U   15
# 15        U   16
# 16        U   16
# 17        U   16
# 18        U   17
# 19        U   16
# 20        U   15
# 21        U   15
# 22        U   16
# 23        U   16
# 24        R   15
# 25        U   16
# 26        U   15
# 27        U   15
# 28        U   16
# 29        U   16
# 30        U   15
# 31        U   15
# 32        R   15
# 33        U   15
# 34        U   16
# 35        U   15
# 36        U   15
# 37        R   16
# 38        R   15
# 39        R   15
# 40        U   16
# 41        U   15
# 42        U   15
# 43        U   15
# 44        U   16
# 45        U   15
# 46        U   16
# 47        U   16
# 48        U   15
# 49        U   15
# 50        U   16
# 51        U   15
# 52        U   15
# ...

# %%
df["age"].mean()
# Out:
# 16.696202531645568

# %%
df['age'].mode()
# Out:
# 0    16
# Name: age, dtype: int64

# %%
df["age"].median()
# Out:
# 17.0

# %%
df["age"].value_counts()
# Out:
# age
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   feespaid  ecactivities  internet  freetime goout health absences  G1  G2  G3
# 0       no            no        no         3     4      3        6   5   6   6
# 1       no            no       yes         3     3      3        4   5   5   6
# 2      yes            no       yes         3     2      3       10   7   8  10
# 3      yes           yes       yes         2     2      5        2  15  14  15
# 4      yes            no        no         3     2      5        4   6  10  10
#
# [5 rows x 26 columns]

# %%
import matplotlib.pyplot as plt

# %%
df["age"].value_counts().plot(kind="bar",title="age",color="green")
# Out:
# <Axes: title={'center': 'age'}, xlabel='age'>

# %%
df["age"].value_counts().plot(kind="pie",title="age",color="red")
# Out:
# <Axes: title={'center': 'age'}, ylabel='count'>

# %%
df.isnull().sum()
# Out:
# school          0
# sex             0
# age             0
# address         0
# famsize         0
# Pstatus         0
# Medu            0
# Fedu            0
# Mjob            2
# Fjob            0
# guardian        0
# traveltime      0
# studytime       0
# failures        0
# Ssupport        0
# Gsupport        0
# feespaid        0
# ecactivities    0
# internet        0
# freetime        0
# goout           0
# health          0
# absences        0
# G1              0
# G2              0
# G3              0
# dtype: int64

# %%
df.dropna()
#remove rows that contain empty cells
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 11      GP   F   15       U     GT3       T     2     1  services     other
# ...

# %%
df.isnull().sum()
# Out:
# school          0
# sex             0
# age             0
# address         0
# famsize         0
# Pstatus         0
# Medu            0
# Fedu            0
# Mjob            0
# Fjob            0
# guardian        0
# traveltime      0
# studytime       0
# failures        0
# Ssupport        0
# Gsupport        0
# feespaid        0
# ecactivities    0
# internet        0
# freetime        0
# goout           0
# health          0
# absences        0
# G1              0
# G2              0
# G3              0
# col             0
# dtype: int64

# %%
df[sdf["address"].isnull()]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, guardian, traveltime, studytime, failures, Ssupport, Gsupport, feespaid, ecactivities, internet, freetime, goout, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 26 columns]

# %%
df["Age"]=df["age"].fillna(df["age"].mean())

# %%
df[df["age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, guardian, traveltime, studytime, failures, Ssupport, Gsupport, feespaid, ecactivities, internet, freetime, goout, health, absences, G1, G2, G3, Age]
# Index: []

# %%
df.groupby("sex").describe()
# Groupby is a tool that helps you organize data into groups based on certain criteria, like the values in a column.
# Out:
#        age                                                      Medu  \
#      count       mean       std   min   25%   50%   75%   max  count
# sex
# F    208.0  16.730769  1.201696  15.0  16.0  17.0  18.0  20.0  208.0
# M    187.0  16.657754  1.356181  15.0  16.0  16.0  18.0  22.0  187.0
#
#                ...    G2           G3                                       \
#          mean  ...   75%   max  count       mean       std  min  25%   50%
# sex            ...
# F    2.668269  ...  13.0  18.0  208.0   9.966346  4.622338  0.0  8.0  10.0
# M    2.839572  ...  14.0  19.0  187.0  10.914439  4.495297  0.0  9.0  11.0
#
#
#       75%   max
# sex
# F    13.0  19.0
# M    14.0  20.0
#
# [2 rows x 104 columns]

# %%
df.to_csv('data2.csv')
